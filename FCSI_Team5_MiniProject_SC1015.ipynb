# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn as skln
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingRegressor, IsolationForest, RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import ElasticNet, LinearRegression, Ridge
from sklearn.metrics import (explained_variance_score, mean_absolute_error,
                             mean_squared_error, mean_squared_log_error, r2_score)
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score, train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import (OrdinalEncoder, PolynomialFeatures,
                                   StandardScaler)
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.utils import shuffle
from xgboost import XGBRegressor
from scipy.stats import shapiro, levene

# %% [markdown]
# Description - Over here we imported the libraries and by importing the libraries we are setting up a path for data analysis, evaluation and model training.

# %%
nba_salary = pd.read_csv("./nba_salaries_2022_2023/nba_salaries.csv")
nba_salary.head()
# Out:
#    Unnamed: 0        Player Name    Salary Position  Age     Team  GP  GS  \
# 0           0      Stephen Curry  48070014       PG   34      GSW  56  56
# 1           1          John Wall  47345760       PG   32      LAC  34   3
# 2           2  Russell Westbrook  47080179       PG   34  LAL/LAC  73  24
# 3           3       LeBron James  44474988       PF   38      LAL  55  54
# 4           4       Kevin Durant  44119845       PF   34  BRK/PHO  47  47
#
#      MP    FG  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# 0 34.70 10.00  ... 0.70 5.40 6.10 6.30 0.90 0.40 3.20 2.10 29.40
# 1 22.20  4.10  ... 0.40 2.30 2.70 5.20 0.80 0.40 2.40 1.70 11.40
# 2 29.10  5.90  ... 1.20 4.60 5.80 7.50 1.00 0.50 3.50 2.20 15.90
# 3 35.50 11.10  ... 1.20 7.10 8.30 6.80 0.90 0.60 3.20 1.60 28.90
# 4 35.60 10.30  ... 0.40 6.30 6.70 5.00 0.70 1.40 3.30 2.10 29.10
#
#    Player-additional
# 0          curryst01
# 1           walljo01
# 2          westbru01
# 3          jamesle01
# 4          duranke01
#
# [5 rows x 32 columns]

# %% [markdown]
# Description - Over here we imported the Kaggle dataset on NBA Salaries and this code gives an idea and sight of the content and structure of the dataset.

# %%
column_to_drop = ['Unnamed: 0','Player Name','Player-additional']  # Change this to the name of the column you want to remove
# Drop the specified column
nba_salary = nba_salary.drop(column_to_drop, axis=1)
nba_salary
# Out:
#        Salary Position  Age     Team  GP  GS    MP    FG   FGA  FG%  ...  FT%  \
# 0    48070014       PG   34      GSW  56  56 34.70 10.00 20.20 0.49  ... 0.92
# 1    47345760       PG   32      LAC  34   3 22.20  4.10  9.90 0.41  ... 0.68
# 2    47080179       PG   34  LAL/LAC  73  24 29.10  5.90 13.60 0.44  ... 0.66
# 3    44474988       PF   38      LAL  55  54 35.50 11.10 22.20 0.50  ... 0.77
# 4    44119845       PF   34  BRK/PHO  47  47 35.60 10.30 18.30 0.56  ... 0.92
# ..        ...      ...  ...      ...  ..  ..   ...   ...   ...  ...  ...  ...
# 462     35096       SF   23      POR   4   0 22.30  1.80  5.80 0.30  ... 0.00
# 463     32795       SG   25      CHO   5   0  5.60  0.20  1.20 0.17  ... 1.00
# 464     32171       SG   29      IND   3   0 18.70  2.70  7.00 0.38  ... 1.00
# 465      5849       PF   23      BRK   1   0 35.00  6.00 12.00 0.50  ... 1.00
# 466      5849       PG   24      MEM   1   0 41.00  1.00  3.00 0.33  ...  NaN
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0   0.70 5.40 6.10 6.30 0.90 0.40 3.20 2.10 29.40
# 1   0.40 2.30 2.70 5.20 0.80 0.40 2.40 1.70 11.40
# 2   1.20 4.60 5.80 7.50 1.00 0.50 3.50 2.20 15.90
# 3   1.20 7.10 8.30 6.80 0.90 0.60 3.20 1.60 28.90
# 4   0.40 6.30 6.70 5.00 0.70 1.40 3.30 2.10 29.10
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...
# 462 0.80 3.00 3.80 1.00 0.50 1.30 1.00 2.30  4.30
# 463 0.20 0.60 0.80 1.00 0.00 0.40 0.20 0.00  1.00
# 464 0.00 2.00 2.00 1.70 0.70 0.00 0.00 1.70  8.00
# 465 3.00 6.00 9.00 7.00 0.00 1.00 4.00 5.00 16.00
# 466 0.00 4.00 4.00 7.00 3.00 0.00 2.00 3.00  3.00
#
# [467 rows x 29 columns]

# %% [markdown]
# Description - Before we proceeded with our Exploratory Data Analysis initially we did a basic data exploration. Additionally we did some data cleaning, examined some of the datsets and provided some basic summary stats.

# %%
print(nba_salary.dtypes)
# Out:
# Salary        int64
# Position     object
# Age           int64
# Team         object
# GP            int64
# GS            int64
# MP          float64
# FG          float64
# FGA         float64
# FG%         float64
# 3P          float64
# 3PA         float64
# 3P%         float64
# 2P          float64
# 2PA         float64
# 2P%         float64
# eFG%        float64
# FT          float64
# FTA         float64
# FT%         float64
# ORB         float64
# DRB         float64
# TRB         float64
# AST         float64
# STL         float64
# BLK         float64
# TOV         float64
# PF          float64
# PTS         float64
# dtype: object

# %%
sal = pd.DataFrame(nba_salary['Salary'])
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sal.describe()
# Out:
#            Salary
# count      467.00
# mean   8416598.75
# std   10708118.05
# min       5849.00
# 25%    1782621.00
# 50%    3722040.00
# 75%   10633543.50
# max   48070014.00

# %%
age = pd.DataFrame(nba_salary['Age'])
pd.set_option('display.float_format', lambda x: '%.2f' % x)
age.describe()
# Out:
#          Age
# count 467.00
# mean   25.82
# std     4.28
# min    19.00
# 25%    23.00
# 50%    25.00
# 75%    29.00
# max    42.00

# %% [markdown]
# Exploratory Data Analysis
#
# Description - Over here we performed EDA and plotted the salary distribution of NBA players using a histogram which gave us a glimpse into the salary distribution of NBA players. The histogram ploted the salary frequency against the various salary ranges.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(nba_salary['Salary'], bins=20, kde=True, color='green')
plt.title('Salaries - Distribution')
plt.xlabel('Salaries in millions')
plt.ylabel('freq')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Representation of salaries by bar graph
#
# Description - Over here we categorize NBA player salaries into different categories and ranges. We visualize the frequency of each salary range using a bar graph. This helps us understand the distribution of NBA salaries even further.

# %%
bins = [0, 1e6,2e6,3e6,4e6,5e6, 10e6, 15e6, 20e6, 25e6, 30e6, 35e6,40e6,45e6,50e6]  # Continue as needed
labels = ['0-1 million','1-2 million','2-3 million','3-4 million','4-5 million', '5-10 million', '10-15 million', '15-20 million', '20-25 million', '25-30 million', '30-35 million', '35-40 million', '40-45 million','45-50 million']  # Match bin ranges

sal['Salary Range'] = pd.cut(sal['Salary'], bins=bins, labels=labels, right=False)

print(sal.head())

# Plot the data
f = plt.figure(figsize=(16, 8))
ax = sns.countplot(data=sal, x='Salary Range')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# Improve x-axis labels readability
plt.xticks(rotation=45)
plt.show()
# Out:
#      Salary   Salary Range
# 0  48070014  45-50 million
# 1  47345760  45-50 million
# 2  47080179  45-50 million
# 3  44474988  40-45 million
# 4  44119845  40-45 million
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Accounting for missing values
#
# Description - Over here we account for the missing values in the dataset and we visualize the effect of missing values on the median of NBA Player salaries for each feature which helps us in understanding potential implications in the modelling and processing of data.

# %%
features_with_na=[features for features in nba_salary.columns if nba_salary[features].isnull().sum()>1]

for feature in features_with_na:
    print(feature, np.round(nba_salary[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# 3P% 0.0278  % missing values
# 2P% 0.0086  % missing values
# FT% 0.0493  % missing values

# %%
for feature in features_with_na:
    data = nba_salary.copy()
    
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    data.groupby(feature)['Salary'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# Representation of numerical and categorical variables separately
#
# Description - Over here we gain valuable insight into the dataset and its structure by presenting the numerical and categorical variables seperately. This helps us understand the different variable types present in the dataset, which is useful modelling and analysis of data.

# %%
# list of numerical variables
numerical_features = [feature for feature in nba_salary.columns if nba_salary[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
nba_salary[numerical_features].head()
# Out:
# Number of numerical variables:  27
#      Salary  Age  GP  GS    MP    FG   FGA  FG%   3P   3PA  ...  FT%  ORB  \
# 0  48070014   34  56  56 34.70 10.00 20.20 0.49 4.90 11.40  ... 0.92 0.70
# 1  47345760   32  34   3 22.20  4.10  9.90 0.41 1.00  3.20  ... 0.68 0.40
# 2  47080179   34  73  24 29.10  5.90 13.60 0.44 1.20  3.90  ... 0.66 1.20
# 3  44474988   38  55  54 35.50 11.10 22.20 0.50 2.20  6.90  ... 0.77 1.20
# 4  44119845   34  47  47 35.60 10.30 18.30 0.56 2.00  4.90  ... 0.92 0.40
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0 5.40 6.10 6.30 0.90 0.40 3.20 2.10 29.40
# 1 2.30 2.70 5.20 0.80 0.40 2.40 1.70 11.40
# 2 4.60 5.80 7.50 1.00 0.50 3.50 2.20 15.90
# 3 7.10 8.30 6.80 0.90 0.60 3.20 1.60 28.90
# 4 6.30 6.70 5.00 0.70 1.40 3.30 2.10 29.10
#
# [5 rows x 27 columns]

# %%
#nba_salaries = nba_salaries.drop(columns=['Player Name','Player-additional'])

categorical_features=[feature for feature in nba_salary.columns if data[feature].dtypes=='O']
print('Number of categorical variables: ', len(categorical_features))

nba_salary[categorical_features].head()
# Out:
# Number of categorical variables:  2
#   Position     Team
# 0       PG      GSW
# 1       PG      LAC
# 2       PG  LAL/LAC
# 3       PF      LAL
# 4       PF  BRK/PHO

# %% [markdown]
# Position vs Salary & Team vs salary
#
# Description - We create a series of bar graphs, with each displaying the median salaries for different categories within a categorical variable providing us with knowledge on how salaries vary across different categories, helping us spot trends in the dataset.

# %%
for feature in categorical_features:
    plt.figure(figsize=(12, 10))
    data=nba_salary.copy()
    data.groupby(feature)['Salary'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Salary')
    plt.title(feature)
    plt.show()

# %% [markdown]
# Correlation of numerical variables with salary
#
# Description - Over here we do an analysis of the correlations of the various numerical features in the dataset and we present the correlation using a heatmap providing us a glimpse of the correlation between different numerical features and the 'NBA Salary' variable.

# %%
nba_salary_num = nba_salary[numerical_features]
sal_corr_matrix = nba_salary_num.corr()
plt.figure(figsize=(12, 12))
heatmap = sns.heatmap(nba_salary_num.corr()[['Salary']].sort_values(by='Salary', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Salary', fontdict={'fontsize':18}, pad=16);

# %%
variable = 'Salary'

high_corr_65 = sal_corr_matrix[variable][sal_corr_matrix[variable] > 0.65]

high_corr_65 = high_corr_65.drop(variable, errors='ignore')  # Safe to ignore if the variable is not in the index

print(f"\nVariables with correlation greater than 0.65 with respect to '{variable}':")
print(high_corr_65)
# Out:
# Variables with correlation greater than 0.65 with respect to 'Salary':
# FG    0.72
# FGA   0.71
# 2P    0.68
# 2PA   0.68
# FT    0.67
# FTA   0.67
# PTS   0.73
# Name: Salary, dtype: float64

# %%
trb = pd.DataFrame(nba_salary['TRB'])
pd.set_option('display.float_format', lambda x: '%.2f' % x)
trb.describe()
# Out:
#          TRB
# count 467.00
# mean    3.53
# std     2.28
# min     0.00
# 25%     1.90
# 50%     3.00
# 75%     4.50
# max    12.50

# %% [markdown]
# Visualization of TRB(Total rebounds)
#
# Description - Over here we present the frequency distribution of total rebounds using a bar graph categoried into different ranges, which provides us with a greater understanding of the distribution of total rebounds of NBA players.

# %%
trb_bins = range(0, 14)  # Bins from 0 to 12
trb_labels = [str(i) for i in trb_bins[:-1]]  # Labels for bins


sal['TRB Range'] = pd.cut(nba_salary['TRB'], bins=trb_bins, labels=trb_labels, right=False)

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=sal, x='TRB Range', palette='viridis')

# Add frequency labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')

plt.xlabel('Total Rebounds (TRB)')
plt.ylabel('Frequency')
plt.title('Frequency of Total Rebounds (TRB)')
plt.xticks(rotation=0)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
gs = pd.DataFrame(nba_salary['GS'])
pd.set_option('display.float_format', lambda x: '%.2f' % x)
gs.describe()
# Out:
#           GS
# count 467.00
# mean   22.65
# std    27.09
# min     0.00
# 25%     1.00
# 50%     8.00
# 75%    45.50
# max    83.00

# %% [markdown]
# Visualization of GS(games played)
#
# Description - Over here we present the frequency distribution of games started using a bar graph. This provides us with a greater understanding of the distribution of games started for NBA Players.

# %%
# Define bins and their labels
gs_bins = [i for i in range(0, 91, 10)]  # Bins from 0 to 83 in increments of 10
gs_labels = [f"{gs}-{gs+9}" for gs in gs_bins[:-1]]  # Labels for bins

sal['GS Range'] = pd.cut(nba_salary['GS'], bins=gs_bins, labels=gs_labels, right=False)

plt.figure(figsize=(12, 6))
ax = sns.countplot(data=sal, x='GS Range', palette='viridis')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')

# Improve x-axis labels readability
plt.xlabel('Games Started (GS)')
plt.ylabel('Frequency')
plt.title('Frequency of Games Started (GS)')
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Visualization of selected numerical variables
#
# Description - Over here we present box plots showing distribution of the selected variables which are 'FG', 'FGA', '2P', '2PA', 'FT', 'FTA' and 'PTS'. This helps us understanding the spread of data, detect anomalies and compare distributions of different variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting variables of interest
variables = ['FG', 'FGA', '2P', '2PA', 'FT', 'FTA', 'PTS']

plt.figure(figsize=(10, 6))
sns.boxplot(data=nba_salary[variables])
plt.title('Box Plot of NBA Salary Variables')
plt.xlabel('Variables')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# PCA Visualization
#
# Description - The below codes demonstrates a detailed analysis of the dataset. This includes outlier detection, croos-validation, model evaluation, model training and correlation analysis which provides us a glimpse into the features of the dataset and the potential relationships between variables.

# %%
data_output = nba_salary['Salary']
data_features = nba_salary[numerical_features].drop(columns = ['Salary'])

data = np.column_stack((data_features, data_output))  # Combined data
data[np.isnan(data)] = 0
# Fit Isolation Forest model
clf = IsolationForest(contamination=0.1)  # Adjust contamination based on expected proportion of outliers
clf.fit(data)

# Predict outliers
outliers = clf.predict(data)
outliers_indices = np.where(outliers == -1)[0]

df = pd.DataFrame(outliers)
# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization
data_pca = pca.fit_transform(data)

most_influential_features = np.abs(pca.components_).argmax(axis=1)
feature_names = [f"Feature {index+1}" for index in most_influential_features]

# Visualize outliers in reduced 2D space
plt.figure(figsize=(8, 6))
plt.scatter(data_pca[:, 0], data_pca[:, 1], c=outliers, cmap='coolwarm', label='Normal Data')
plt.scatter(data_pca[outliers_indices, 0], data_pca[outliers_indices, 1], color='red', marker='x', label='Outliers')
plt.title('PCA Visualization of Outliers with Selected Features')
plt.xlabel(feature_names[0])  # Use the name of the most influential feature for PC1
plt.ylabel(feature_names[1])  # Use the name of the most influential feature for PC2
plt.colorbar(label='Outlier Prediction (-1: Outlier, 1: Inlier)')
plt.legend()
plt.show()

# %% [markdown]
# Performing the Shapiro-Wilk and Levene's test on Salary ( using 2-pointer(2P) as the base variable)

# %%
nba_salary['Salary'] = np.log(nba_salary['Salary'])

column = 'Salary'

_, shapiro_pvalue = shapiro(nba_salary[column])
print(f"Shapiro-Wilk test p-value for {column}: {shapiro_pvalue}")

salary_by_category = [group for name, group in nba_salary.groupby('2P')['Salary']]
_, levene_pvalue = levene(*salary_by_category)  # Unpack list
print(f"Levene's test p-value for {column}: {levene_pvalue}")
# Out:
# Shapiro-Wilk test p-value for Salary: 4.298769396005042e-10
# Levene's test p-value for Salary: 0.2031870115694686

# %% [markdown]
# After Normalisation of the Salary Variable

# %%
plt.figure(figsize=(10, 6))
sns.histplot(nba_salary['Salary'], bins=20, kde=True, color='green')
plt.title('Salaries - Distribution')
plt.xlabel('Salaries in millions')
plt.ylabel('freq')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Variable of interest
variable = 'Salary'

high_corr_55 = sal_corr_matrix[variable][(sal_corr_matrix[variable] >=0.50) & (sal_corr_matrix[variable]<=0.65)]

high_corr_55 = high_corr_55.drop(variable, errors='ignore')  # Safe to ignore if the variable is not in the index

# Print the results
print(f"\nVariables with correlation greater than or equal to 0.50 and less than or equal to 0.65 with respect to '{variable}':")
print(high_corr_55)
# Out:
# Variables with correlation greater than or equal to 0.50 and less than or equal to 0.65 with respect to 'Salary':
# GS    0.60
# MP    0.64
# DRB   0.58
# TRB   0.50
# AST   0.59
# TOV   0.65
# Name: Salary, dtype: float64

# %%
MP = pd.DataFrame(nba_salary['MP'])
pd.set_option('display.float_format', lambda x: '%.2f' % x)
print(MP.describe())
GS = pd.DataFrame(nba_salary['GS'])
pd.set_option('display.float_format', lambda x: '%.2f' % x)
print(GS.describe())
# Out:
#           MP
# count 467.00
# mean   19.87
# std     9.55
# min     1.80
# 25%    12.50
# 50%    19.20
# 75%    28.30
# max    41.00
#           GS
# count 467.00
# mean   22.65
# std    27.09
# min     0.00
# 25%     1.00
# 50%     8.00
# 75%    45.50
# max    83.00

# %% [markdown]
# Creating 3 separate categorical variables from numerical variables
#
# Description - Over here we create 3 seperate categorical variables (GS_Grade, TRB_Category, MP range) by use of binning. The binning techniques convert numerical columns into categorical variables which allows for analysis and a greater understanding of these variable based on predefined categories.

# %% [markdown]
# GS_Grade

# %%
if nba_salary['GS'].isnull().any():
    median_gs = nba_salary['GS'].median()
    nba_salary['GS'].fillna(median_gs, inplace=True)

num_bins = 9

bin_edges = nba_salary['GS'].quantile(np.linspace(0, 1, num_bins + 1))

bin_edges = np.unique(bin_edges)

labels = range(1, len(bin_edges))

# Create the categorical column
nba_salary['GS_Grade'] = pd.cut(nba_salary['GS'], bins=bin_edges, labels=labels, include_lowest=True)

nba_salary.head()
# Out:
#    Salary Position  Age     Team  GP  GS    MP    FG   FGA  FG%  ...  ORB  \
# 0   17.69       PG   34      GSW  56  56 34.70 10.00 20.20 0.49  ... 0.70
# 1   17.67       PG   32      LAC  34   3 22.20  4.10  9.90 0.41  ... 0.40
# 2   17.67       PG   34  LAL/LAC  73  24 29.10  5.90 13.60 0.44  ... 1.20
# 3   17.61       PF   38      LAL  55  54 35.50 11.10 22.20 0.50  ... 1.20
# 4   17.60       PF   34  BRK/PHO  47  47 35.60 10.30 18.30 0.56  ... 0.40
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS  GS_Grade
# 0 5.40 6.10 6.30 0.90 0.40 3.20 2.10 29.40         6
# 1 2.30 2.70 5.20 0.80 0.40 2.40 1.70 11.40         2
# 2 4.60 5.80 7.50 1.00 0.50 3.50 2.20 15.90         4
# 3 7.10 8.30 6.80 0.90 0.60 3.20 1.60 28.90         6
# 4 6.30 6.70 5.00 0.70 1.40 3.30 2.10 29.10         5
#
# [5 rows x 30 columns]

# %% [markdown]
# TRB_Category

# %%
trb_bins = [0, 3, 6, 9, 12]
trb_labels = ['D', 'C', 'B', 'A']

nba_salary['TRB'].fillna(-1, inplace=True)

nba_salary['TRB_Category'] = pd.cut(nba_salary['TRB'], bins=trb_bins, labels=trb_labels, right=False)

nba_salary['TRB_Category'] = nba_salary['TRB_Category'].cat.add_categories('Unknown').fillna('Unknown')

# Print the first few rows to verify
nba_salary.head()
# Out:
#    Salary Position  Age     Team  GP  GS    MP    FG   FGA  FG%  ...  DRB  \
# 0   17.69       PG   34      GSW  56  56 34.70 10.00 20.20 0.49  ... 5.40
# 1   17.67       PG   32      LAC  34   3 22.20  4.10  9.90 0.41  ... 2.30
# 2   17.67       PG   34  LAL/LAC  73  24 29.10  5.90 13.60 0.44  ... 4.60
# 3   17.61       PF   38      LAL  55  54 35.50 11.10 22.20 0.50  ... 7.10
# 4   17.60       PF   34  BRK/PHO  47  47 35.60 10.30 18.30 0.56  ... 6.30
#
#    TRB  AST  STL  BLK  TOV   PF   PTS  GS_Grade  TRB_Category
# 0 6.10 6.30 0.90 0.40 3.20 2.10 29.40         6             B
# 1 2.70 5.20 0.80 0.40 2.40 1.70 11.40         2             D
# 2 5.80 7.50 1.00 0.50 3.50 2.20 15.90         4             C
# 3 8.30 6.80 0.90 0.60 3.20 1.60 28.90         6             B
# 4 6.70 5.00 0.70 1.40 3.30 2.10 29.10         5             B
#
# [5 rows x 31 columns]

# %% [markdown]
# MP range

# %%
bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]  # Continue as needed
labels = ['0-5 minutes', '5-10 minutes', '10-15 minutes', '15-20 minutes', '20-25 minutes', '25-30 minutes', '30-35 minutes', '35-40 minutes', '40-45 minutes']   # Match bin ranges

MP['MP range'] = pd.cut(MP['MP'], bins=bins, labels=labels, right=False)

print(MP.head())

f = plt.figure(figsize=(16, 8))
ax = sns.countplot(data=MP, x='MP range')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.xticks(rotation=45)
plt.show()
# Out:
#      MP       MP range
# 0 34.70  30-35 minutes
# 1 22.20  20-25 minutes
# 2 29.10  25-30 minutes
# 3 35.50  35-40 minutes
# 4 35.60  35-40 minutes
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Description - The provided code first checks the correlation between the existing categorical variables (position and team name) and the target variable, 'Salary', finding it to be low. Subsequently,we create three new categorical variables to potentially capture different aspects of the data that may have a stronger correlation with salary.

# %%
label_encoder = LabelEncoder()
nba_salary['Position'] = label_encoder.fit_transform(nba_salary['Position'])

# Check correlation between 'Salary' and 'GS_Grade_Encoded'
correlation = nba_salary[['Salary', 'Position']].corr()
print(correlation)
# Out:
#           Salary  Position
# Salary      1.00     -0.07
# Position   -0.07      1.00

# %%
nba_salary['Team'] = label_encoder.fit_transform(nba_salary['Team'])

correlation = nba_salary[['Salary', 'Team']].corr()
print(correlation)
# Out:
#         Salary  Team
# Salary    1.00 -0.06
# Team     -0.06  1.00

# %%
correlation = nba_salary[['Salary', 'GS_Grade']].corr()

print(correlation)

label_encoder = LabelEncoder()
print()
nba_salary['TRB_Category'] = label_encoder.fit_transform(nba_salary['TRB_Category'])

correlation = nba_salary[['Salary', 'TRB_Category']].corr()

print(correlation)
print()
correlation = nba_salary[['Salary', 'MP']].corr()

print(correlation)
# Out:
#           Salary  GS_Grade
# Salary      1.00      0.63
# GS_Grade    0.63      1.00
#
#               Salary  TRB_Category
# Salary          1.00         -0.38
# TRB_Category   -0.38          1.00
#
#         Salary   MP
# Salary    1.00 0.62
# MP        0.62 1.00

# %%
num_bins = 9
bin_edges = nba_salary['MP'].quantile(np.linspace(0, 1, num_bins + 1))

bin_edges = np.unique(bin_edges)

labels = range(1, len(bin_edges))

nba_salary['MP_Grade'] = pd.cut(nba_salary['MP'], bins=bin_edges, labels=labels, include_lowest=True)

nba_salary
# Out:
#      Salary  Position  Age  Team  GP  GS    MP    FG   FGA  FG%  ...  TRB  \
# 0     17.69         2   34    26  56  56 34.70 10.00 20.20 0.49  ... 6.10
# 1     17.67         2   32    33  34   3 22.20  4.10  9.90 0.41  ... 2.70
# 2     17.67         2   34    38  73  24 29.10  5.90 13.60 0.44  ... 5.80
# 3     17.61         1   38    36  55  54 35.50 11.10 22.20 0.50  ... 8.30
# 4     17.60         1   34     9  47  47 35.60 10.30 18.30 0.56  ... 6.70
# ..      ...       ...  ...   ...  ..  ..   ...   ...   ...  ...  ...  ...
# 462   10.47         4   23    65   4   0 22.30  1.80  5.80 0.30  ... 3.80
# 463   10.40         7   25    13   5   0  5.60  0.20  1.20 0.17  ... 0.80
# 464   10.38         7   29    32   3   0 18.70  2.70  7.00 0.38  ... 2.00
# 465    8.67         1   23     4   1   0 35.00  6.00 12.00 0.50  ... 9.00
# 466    8.67         2   24    43   1   0 41.00  1.00  3.00 0.33  ... 4.00
#
#      AST  STL  BLK  TOV   PF   PTS  GS_Grade  TRB_Category  MP_Grade
# 0   6.30 0.90 0.40 3.20 2.10 29.40         6             1         9
# 1   5.20 0.80 0.40 2.40 1.70 11.40         2             3         6
# 2   7.50 1.00 0.50 3.50 2.20 15.90         4             2         7
# 3   6.80 0.90 0.60 3.20 1.60 28.90         6             1         9
# 4   5.00 0.70 1.40 3.30 2.10 29.10         5             1         9
# ..   ...  ...  ...  ...  ...   ...       ...           ...       ...
# 462 1.00 0.50 1.30 1.00 2.30  4.30         1             2         6
# 463 1.00 0.00 0.40 0.20 0.00  1.00         1             3         1
# 464 1.70 0.70 0.00 0.00 1.70  8.00         1             3         5
# 465 7.00 0.00 1.00 4.00 5.00 16.00         1             0         9
# 466 7.00 3.00 0.00 2.00 3.00  3.00         1             2         9
#
# [467 rows x 32 columns]

# %% [markdown]
# Machine Learning Models

# %% [markdown]
# Linear Regression

# %%
from sklearn.model_selection import cross_val_score

imputer = SimpleImputer(strategy='mean')
imp_x = imputer.fit_transform(data_features)
imp_y = imputer.fit_transform(data_output.values.reshape(-1, 1))

X_train, X_test, y_train, y_test = train_test_split(imp_x, imp_y, test_size=0.2, random_state=2)

normal_model = LinearRegression()

cv_scores = cross_val_score(normal_model, X_train, y_train, cv=5, scoring='r2')

cv_r2 = cv_scores.mean()

cv_mse_scores = -cross_val_score(normal_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
cv_mse = cv_mse_scores.mean()

print("Cross-Validated Model MSE:", cv_mse)
print("Cross-Validated Model R^2:", cv_r2)
# Out:
# Cross-Validated Model MSE: 39220476811918.375
# Cross-Validated Model R^2: 0.6554933439990391

# %%
normal_data_features = data_features[df[0] == 1]  # Subset of normal data
outliers_data_features = data_features[df[0] == -1]  # Subset of outliers
normal_data_output = data_output[df[0] == 1]
outliers_data_output = data_output[df[0] == -1]
imputer = SimpleImputer(strategy='mean')  # Use mean imputation, you can choose another strategy
normal_data_imputed = imputer.fit_transform(normal_data_features)
outliers_data_imputed = imputer.transform(outliers_data_features)

# %%
X_train_normal, X_test_normal, y_train_normal, y_test_normal = train_test_split(normal_data_imputed, normal_data_output, test_size=0.2, random_state=10)
X_train_normal.shape, X_test_normal.shape

normal_model = LinearRegression()
normal_model.fit(X_train_normal, y_train_normal)
y_pred_normal = normal_model.predict(X_test_normal)
normal_mse = mean_squared_error(y_test_normal, y_pred_normal)
Scorer2 = r2_score(y_test_normal, y_pred_normal)
print("Normal Data Model MSE:", normal_mse)
print("Normal Data Model R^2:", Scorer2)

if len(outliers) > 0:
    X_train_outliers, X_test_outliers, y_train_outliers, y_test_outliers = train_test_split(outliers_data_imputed, outliers_data_output, test_size=0.2, random_state=10)
    outliers_model = LinearRegression()
    outliers_model.fit(X_train_outliers, y_train_outliers)
    y_pred_outliers = outliers_model.predict(X_test_outliers)
    outliers_mse = mean_squared_error(y_test_outliers, y_pred_outliers)
    Scorer3 = r2_score(y_test_outliers, y_pred_outliers)
    print("Outliers Data Model MSE:", outliers_mse)
    print("Outliers Data Model R^2:", Scorer3)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(y_test_outliers, y_pred_outliers, color='red')
plt.plot([y_test_outliers.min(), y_test_outliers.max()], [y_test_outliers.min(), y_test_outliers.max()], 'k--', lw=2)
m, b = np.polyfit(y_test_outliers, y_pred_outliers, 1)  # Compute slope and intercept
plt.plot(y_test_outliers, m * y_test_outliers + b, color='blue', linewidth=2)  # Plot linear regression line
plt.xlabel('Actual Salaries')
plt.ylabel('Predicted Salaries')
plt.title('Outliers Data: Actual vs Predicted Salaries')

plt.subplot(1, 2, 2)
plt.scatter(y_test_normal, y_pred_normal, color='blue')
plt.plot([y_test_normal.min(), y_test_normal.max()], [y_test_normal.min(), y_test_normal.max()], 'k--', lw=2)
m, b = np.polyfit(y_test_normal, y_pred_normal, 1)  # Compute slope and intercept
plt.plot(y_test_normal, m * y_test_normal + b, color='red', linewidth=2)  # Plot linear regression line
plt.xlabel('Actual Salaries')
plt.ylabel('Predicted Salaries')
plt.title('Normal Data: Actual vs Predicted Salaries')

plt.tight_layout()
plt.show()
# Out:
# Normal Data Model MSE: 33012049810873.9
# Normal Data Model R^2: 0.5055359795321057
# Outliers Data Model MSE: 2070991136889689.5
# Outliers Data Model R^2: -6.569018720854935

# %% [markdown]
# We can see that the outliers are important in model prediction. The R^2 value decreased by 0.1. Hence for the future models we will use the data that includes the outliers.

# %% [markdown]
# Random Forest

# %%
X = normal_data_imputed  
y = normal_data_output 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# Initialize Random Forest Regressor
model = RandomForestRegressor(n_estimators=1000, random_state=10)

# Train the model
model.fit(X_train, y_train)

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

train_rmse = mean_squared_error(y_train, y_pred_train, squared=False)
test_rmse = mean_squared_error(y_test, y_pred_test, squared=False)
print(f'Training RMSE for Random forest: {train_rmse}')
print(f'Test RMSE for Random forest: {test_rmse}')
# Out:
# Training RMSE for Random forest: 1875312.9677415495
# Test RMSE for Random forest: 6486293.206727798

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=10)

# Selecting features and target variable
X_cat = nba_salary[['MP_Grade', 'TRB_Category', 'GS_Grade']]  # Categorical features
X_num = nba_salary[['FG', 'FGA', '2P', '2PA', 'FT', 'FTA', 'PTS']]   # Numerical features
y = nba_salary['Salary']  # Target variable

# Encode categorical features
ordinal_encoder = OrdinalEncoder()
X_cat_encoded = ordinal_encoder.fit_transform(X_cat)

# Concatenate categorical and numerical features
X = np.concatenate((X_cat_encoded, X_num), axis=1)
X = imputer.fit_transform(X)
# Initialize Random Forest Regressor
model = RandomForestRegressor(n_estimators=1000, random_state=10)

# Perform cross-validation
cv_scores = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
rmse_scores = np.sqrt(-cv_scores)
r2_scores = cross_val_score(model, X, y, cv=kf, scoring='r2')

# Print results
print("Cross-validated RMSE scores:", rmse_scores)
print("Average RMSE across all folds:", np.mean(rmse_scores))
print("Standard deviation of RMSE across all folds:", np.std(rmse_scores))

print("Cross-validated R^2 scores:", r2_scores)
print("Average R^2 across all folds:", np.mean(r2_scores))
print("Standard deviation of R^2 across all folds:", np.std(r2_scores))
# Out:
# Cross-validated RMSE scores: [1.23996488 1.09481317 1.07193983 1.16472804 1.30493194]
# Average RMSE across all folds: 1.1752755716896526
# Standard deviation of RMSE across all folds: 0.08747480157425234
# Cross-validated R^2 scores: [0.3591994  0.45847512 0.44976409 0.44714182 0.37690278]
# Average R^2 across all folds: 0.41829664167348934
# Standard deviation of R^2 across all folds: 0.041575211800999566

# %%
X = normal_data_imputed  # Features
y = normal_data_output  # Target variable

model = RandomForestRegressor(n_estimators=1000, random_state=10)

mse_scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=kf)

rmse_scores = np.sqrt(-mse_scores)
# Perform cross-validation and calculate R^2 scores
r2_scores = cross_val_score(model, X, y, scoring='r2', cv=kf)

print("Cross-validated R^2 scores:", r2_scores)
mean_r2 = np.mean(r2_scores)
print("Mean R^2:", mean_r2)

print("Cross-validated RMSE scores:", rmse_scores)
print("Mean RMSE:", np.mean(rmse_scores))
print("Standard Deviation of RMSE:", np.std(rmse_scores))
# Out:
# Cross-validated R^2 scores: [0.53017904 0.66873088 0.60101439 0.70586817 0.67768257]
# Mean R^2: 0.6366950115142467
# Cross-validated RMSE scores: [5600606.91848835 5367371.06784911 5121993.892185   4799666.33349641
#  5386472.39499596]
# Mean RMSE: 5255222.121402967
# Standard Deviation of RMSE: 273633.15424876526

# %% [markdown]
# Multivariate Polynomial regression

# %% [markdown]
# Description - The following code performs multivariate polynomial regression on NBA player salary data using features like field goals, free throws, and points, and then evaluates the model's performance metrics like mean squared error and R² score.

# %%
X = nba_salary[['FG', 'FGA', '2P', '2PA', 'FT', 'FTA', 'PTS']]
y = nba_salary['Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# Create polynomial features
degree = 2  # Degree of polynomial features
poly_features = PolynomialFeatures(degree=degree)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Fit polynomial regression model
model = LinearRegression()
model.fit(X_train_poly, y_train)

y_pred = model.predict(X_test_poly)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Polynomial Regression Evaluation Metrics:")
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R^2 Score:", r2)
# Out:
# Polynomial Regression Evaluation Metrics:
# Mean Squared Error (MSE): 1.9106067775758322
# Root Mean Squared Error (RMSE): 1.382247003098879
# R^2 Score: 0.20370230240600873

# %% [markdown]
# Description - This code generates a visualization for the polynomial regression model's predicted salary values against actual salaries (using the highly correlated numeric features), showing how well the model fits the test data.

# %%
import matplotlib.pyplot as plt

x_values = np.linspace(X.min(), X.max(), 100)  

x_values_poly = poly_features.transform(x_values)

y_values_pred = model.predict(x_values_poly)

plt.scatter(X_test['PTS'], y_test, color='blue', label='Actual')

# Plot the predicted values
plt.plot(x_values[:, 6], y_values_pred, color='red', label='Predicted')

plt.title('Polynomial Regression')
plt.xlabel('PTS')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
new_df= nba_salary.copy()
# Perform one-hot encoding and concatenate with original DataFrame
new_df = pd.concat([new_df, pd.get_dummies(new_df[categorical_features])], axis=1)

# Drop the original categorical columns if needed
new_df = new_df.drop(categorical_features, axis=1)

print(new_df)
# Out:
#      Salary  Age  GP  GS    MP    FG   FGA  FG%   3P   3PA  ...  TRB  AST  \
# 0     17.69   34  56  56 34.70 10.00 20.20 0.49 4.90 11.40  ... 6.10 6.30
# 1     17.67   32  34   3 22.20  4.10  9.90 0.41 1.00  3.20  ... 2.70 5.20
# 2     17.67   34  73  24 29.10  5.90 13.60 0.44 1.20  3.90  ... 5.80 7.50
# 3     17.61   38  55  54 35.50 11.10 22.20 0.50 2.20  6.90  ... 8.30 6.80
# 4     17.60   34  47  47 35.60 10.30 18.30 0.56 2.00  4.90  ... 6.70 5.00
# ..      ...  ...  ..  ..   ...   ...   ...  ...  ...   ...  ...  ...  ...
# 462   10.47   23   4   0 22.30  1.80  5.80 0.30 0.80  3.00  ... 3.80 1.00
# 463   10.40   25   5   0  5.60  0.20  1.20 0.17 0.20  1.00  ... 0.80 1.00
# 464   10.38   29   3   0 18.70  2.70  7.00 0.38 2.00  6.00  ... 2.00 1.70
# 465    8.67   23   1   0 35.00  6.00 12.00 0.50 2.00  5.00  ... 9.00 7.00
# 466    8.67   24   1   0 41.00  1.00  3.00 0.33 1.00  3.00  ... 4.00 7.00
#
#      STL  BLK  TOV   PF   PTS  GS_Grade  TRB_Category  MP_Grade
# 0   0.90 0.40 3.20 2.10 29.40         6             1         9
# 1   0.80 0.40 2.40 1.70 11.40         2             3         6
# 2   1.00 0.50 3.50 2.20 15.90         4             2         7
# 3   0.90 0.60 3.20 1.60 28.90         6             1         9
# 4   0.70 1.40 3.30 2.10 29.10         5             1         9
# ..   ...  ...  ...  ...   ...       ...           ...       ...
# 462 0.50 1.30 1.00 2.30  4.30         1             2         6
# 463 0.00 0.40 0.20 0.00  1.00         1             3         1
# 464 0.70 0.00 0.00 1.70  8.00         1             3         5
# 465 0.00 1.00 4.00 5.00 16.00         1             0         9
# 466 3.00 0.00 2.00 3.00  3.00         1             2         9
#
# [467 rows x 30 columns]

# %% [markdown]
# Description - preprocessing the data for neural network training by converting categorical variables into numerical ones through one-hot encoding, splitting the dataset into training and testing sets, and scaling numerical features using StandardScaler. Defining and training a basic neural network model to predict NBA player salaries, optimizing the parameters using the Adam optimizer.

# %% [markdown]
# Training a simple neural network with both the one hot encoded categorical variables and the numerical variables.

# %% [markdown]
# Neural network

# %%
new_df_numeric = new_df.apply(pd.to_numeric, errors='ignore')
new_df_encoded = pd.get_dummies(new_df_numeric)
new_df_encoded.dropna(inplace=True)
X = new_df_encoded.drop('Salary', axis=1)
y = new_df_encoded['Salary']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)

class NBA_SalaryPredictor(nn.Module):
    def __init__(self, input_size):
        super(NBA_SalaryPredictor, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

input_size = X_train_tensor.shape[1]
model = NBA_SalaryPredictor(input_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

model.eval()
with torch.no_grad():
    y_pred = model(X_test_tensor)
    mse = criterion(y_pred, y_test_tensor)
    r2 = r2_score(y_test_tensor.numpy(), y_pred.numpy())
    print(f'Mean Squared Error: {mse.item():.4f}')
    print(f'R^2 Score: {r2:.4f}')
# Out:
# Epoch [10/100], Loss: 228.5459
# Epoch [20/100], Loss: 215.6947
# Epoch [30/100], Loss: 197.0492
# Epoch [40/100], Loss: 169.3874
# Epoch [50/100], Loss: 132.2889
# Epoch [60/100], Loss: 91.4431
# Epoch [70/100], Loss: 59.7180
# Epoch [80/100], Loss: 45.4539
# Epoch [90/100], Loss: 39.8854
# Epoch [100/100], Loss: 34.5796
# Mean Squared Error: 34.2583
# R^2 Score: -16.0097

# %% [markdown]
# The neural network is being underfitted.

# %% [markdown]
# XGBoost Regression
# Description - optimizing XGBoost regression for NBA player salary prediction by tuning hyperparameters like learning rate, number of estimators, and maximum depth using GridSearchCV. Evaluating the model's performance through cross-validation.

# %%
y = nba_salary["Salary"]  # Salary y value
X = nba_salary_num.drop(["Salary"], axis=1)

xgb = XGBRegressor()


param_grid = {
    'learning_rate': [0.01, 0.1, 0.2, 0.3],
    'n_estimators': [50, 100, 200, 300, 500],
    'max_depth': [3, 4, 5, 6, 7]
}

grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=kf, scoring='neg_mean_squared_error', verbose=1)
grid_search.fit(X, y)

print("Best Parameters:", grid_search.best_params_)
print("Best Score:", np.sqrt(-grid_search.best_score_))

best_xgb = grid_search.best_estimator_
cv_scores = cross_val_score(best_xgb, X, y, cv=kf, scoring='neg_mean_squared_error')

rmse_scores = np.sqrt(-cv_scores)

r2_scores = cross_val_score(best_xgb, X, y, scoring='r2',cv=kf)

print("Cross-validated RMSE scores:", rmse_scores)
print("Average RMSE across all folds:", np.mean(rmse_scores))
print("Standard deviation of RMSE across all folds:", np.std(rmse_scores))
print("Cross-validated R^2 scores:", r2_scores)
print("Average R^2 across all folds:", np.mean(r2_scores))
print("Standard deviation of R^2 across all folds:", np.std(r2_scores))
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# Best Score: 0.8369266755870293
# Cross-validated RMSE scores: [0.91596879 0.78576671 0.87032674 0.73698829 0.8632397 ]
# Average RMSE across all folds: 0.834458046101887
# Standard deviation of RMSE across all folds: 0.06423417785709887
# Cross-validated R^2 scores: [0.65032426 0.72105046 0.63727895 0.77864678 0.72732652]
# Average R^2 across all folds: 0.7029253943056158
# Standard deviation of R^2 across all folds: 0.052409914546894754
